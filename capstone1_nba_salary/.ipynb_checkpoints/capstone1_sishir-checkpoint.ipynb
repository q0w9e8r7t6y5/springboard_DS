# %% [markdown]
# # Sishir Yeety Capstone 1
#
# milestone 1: https://docs.google.com/document/d/1nE_xoHAVr05yQXmPfOvWT4EDC0Xcp8-ByZOkRPr2clo/edit

# %%
import xlrd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm 
import matplotlib.pyplot as plt 
import pandas as pd
import time
import seaborn as sns
from datetime import datetime

# %%
basic_df = pd.read_excel("basic.xlsx")
advanced_df = pd.read_excel('advanced.xlsx')

# %%
basic_df.head()
# Out:
#         #  Season Start Player Name Player Salary in $ Pos   Age   Tm     G  \
# 0  8035.0        1986.0  A.C. Green                NaN  PF  22.0  LAL  82.0
# 1  8420.0        1987.0  A.C. Green                NaN  PF  23.0  LAL  79.0
# 2  8807.0        1988.0  A.C. Green                NaN  PF  24.0  LAL  82.0
# 3  9242.0        1989.0  A.C. Green                NaN  PF  25.0  LAL  82.0
# 4  9688.0        1990.0  A.C. Green            1750000  PF  26.0  LAL  82.0
#
#      GS      MP   ...      FT%    ORB    DRB    TRB    AST   STL   BLK    TOV  \
# 0   1.0  1542.0   ...    0.611  160.0  221.0  381.0   54.0  49.0  49.0   99.0
# 1  72.0  2240.0   ...    0.780  210.0  405.0  615.0   84.0  70.0  80.0  102.0
# 2  64.0  2636.0   ...    0.773  245.0  465.0  710.0   93.0  87.0  45.0  120.0
# 3  82.0  2510.0   ...    0.786  258.0  481.0  739.0  103.0  94.0  55.0  119.0
# 4  82.0  2709.0   ...    0.751  262.0  450.0  712.0   90.0  66.0  50.0  116.0
#
#       PF     PTS
# 0  229.0   521.0
# ...

# %%
advanced_df.head()
# Out:
#    year   tm          player  age   g    mp   per     ts  3par    ftr  \
# 0  1978  NOJ  Truck Robinson   26  82  3638  15.7  0.481   NaN  0.340
# 1  1978  BUF     Randy Smith   29  82  3314  19.1  0.521   NaN  0.326
# 2  1978  WSB     Elvin Hayes   32  81  3246  17.1  0.489   NaN  0.365
# 3  1978  BOS     Dave Cowens   29  77  3215  18.6  0.533   NaN  0.233
# 4  1978  NYK      Bob McAdoo   26  79  3182  22.0  0.567   NaN  0.412
#
#       ...       d_worp  adjusted_worp  estimated_position  bbref_pos  \
# 0     ...          1.1            1.1                 3.6        4.0
# 1     ...         -2.3            7.4                 1.0        2.0
# 2     ...          3.4            6.5                 4.2        4.0
# 3     ...          6.1           12.5                 3.9        5.0
# 4     ...          2.6           10.6                 3.6        5.0
#
#    age_on_feb_1  yrs_experience  height  weight rounded_position  rounded_age
# ...

# %%
# Let's wrangle the basic statistics first!

# get rid of all players before 2008
basic_df = basic_df[basic_df['Season Start'] >= 2005]

basic_df['Season Start'].unique()
# Out:
# array([2017., 2010., 2011., 2012., 2013., 2014., 2015., 2008., 2009.,
#        2016., 2005., 2006., 2007.])

# %%
basic_df.head()
# Out:
#           #  Season Start   Player Name Player Salary in $ Pos   Age   Tm  \
# 24  24304.0        2017.0  A.J. Hammons            1312611   C  24.0  DAL
# 25  20357.0        2010.0    A.J. Price             762195  PG  23.0  IND
# 26  20966.0        2011.0    A.J. Price             854389  PG  24.0  IND
# 27  21529.0        2012.0    A.J. Price             885120  PG  25.0  IND
# 28  22100.0        2013.0    A.J. Price                NaN  PG  26.0  WAS
#
#        G    GS      MP  ...      FT%   ORB   DRB    TRB    AST   STL   BLK  \
# 24  22.0   0.0   163.0  ...    0.450   8.0  28.0   36.0    4.0   1.0  13.0
# 25  56.0   2.0   865.0  ...    0.800  12.0  76.0   88.0  106.0  35.0   3.0
# 26  50.0   0.0   795.0  ...    0.667  16.0  56.0   72.0  111.0  29.0   1.0
# 27  44.0   1.0   568.0  ...    0.800  13.0  48.0   61.0   86.0  20.0   2.0
# 28  57.0  22.0  1278.0  ...    0.790  20.0  94.0  114.0  205.0  33.0   3.0
#
#      TOV    PF    PTS
# 24  10.0  21.0   48.0
# 25  59.0  53.0  410.0
# ...

# %%
basic_df['blank2'].unique()
# Out:
# array([nan])

# %%
basic_df.columns
# Out:
# Index(['#', 'Season Start', 'Player Name', 'Player Salary in $', 'Pos', 'Age',
#        'Tm', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%',
#        'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS',
#        'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
basic_df = basic_df.drop(['blank2', '#'], axis=1)

# %%
basic_df.columns
# Out:
# Index(['Season Start', 'Player Name', 'Player Salary in $', 'Pos', 'Age', 'Tm',
#        'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS',
#        'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
basic_df = basic_df.drop(['blanl'], axis=1)

# %%
basic_df.columns
# Out:
# Index(['Season Start', 'Player Name', 'Player Salary in $', 'Pos', 'Age', 'Tm',
#        'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
basic_df[basic_df['Player Name'] == 'LeBron James']

# I see some NaN here and there
# Out:
#        Season Start   Player Name Player Salary in $ Pos   Age   Tm     G  \
# 14936        2005.0  LeBron James            4621800  SF  20.0  CLE  80.0
# 14937        2006.0  LeBron James            5828090  SF  21.0  CLE  79.0
# 14938        2007.0  LeBron James           13041250  SF  22.0  CLE  78.0
# 14939        2008.0  LeBron James           14410581  SF  23.0  CLE  75.0
# 14940        2009.0  LeBron James           15779912  SF  24.0  CLE  81.0
# 14941        2010.0  LeBron James                NaN  SF  25.0  CLE  76.0
# 14942        2011.0  LeBron James           16022500  SF  26.0  MIA  79.0
# 14943        2012.0  LeBron James           17545000  SF  27.0  MIA  62.0
# 14944        2013.0  LeBron James           19067500  PF  28.0  MIA  76.0
# 14945        2014.0  LeBron James           20644400  PF  29.0  MIA  77.0
# 14946        2015.0  LeBron James           22971000  SF  30.0  CLE  69.0
# 14947        2016.0  LeBron James           30963450  SF  31.0  CLE  76.0
# ...

# %%
basic_df.head()
# Out:
#     Season Start   Player Name Player Salary in $ Pos   Age   Tm     G    GS  \
# 24        2017.0  A.J. Hammons            1312611   C  24.0  DAL  22.0   0.0
# 25        2010.0    A.J. Price             762195  PG  23.0  IND  56.0   2.0
# 26        2011.0    A.J. Price             854389  PG  24.0  IND  50.0   0.0
# 27        2012.0    A.J. Price             885120  PG  25.0  IND  44.0   1.0
# 28        2013.0    A.J. Price                NaN  PG  26.0  WAS  57.0  22.0
#
#         MP   PER  ...      FT%   ORB   DRB    TRB    AST   STL   BLK   TOV  \
# 24   163.0   8.4  ...    0.450   8.0  28.0   36.0    4.0   1.0  13.0  10.0
# 25   865.0  14.0  ...    0.800  12.0  76.0   88.0  106.0  35.0   3.0  59.0
# 26   795.0  10.7  ...    0.667  16.0  56.0   72.0  111.0  29.0   1.0  53.0
# 27   568.0  11.5  ...    0.800  13.0  48.0   61.0   86.0  20.0   2.0  32.0
# 28  1278.0  12.4  ...    0.790  20.0  94.0  114.0  205.0  33.0   3.0  64.0
#
#       PF    PTS
# 24  21.0   48.0
# 25  53.0  410.0
# ...

# %%
# advanced excel, not really using right now
advanced_df = advanced_df[advanced_df['year'] >= 2005]

advanced_df.head()
# Out:
#        year   tm           player  age   g    mp   per     ts   3par    ftr  \
# 11082  2005  CLE     LeBron James   20  80  3388  25.7  0.554  0.183  0.378
# 11083  2005  NYK  Stephon Marbury   27  82  3281  21.9  0.575  0.248  0.420
# 11084  2005  WAS   Gilbert Arenas   23  80  3274  21.3  0.565  0.369  0.420
# 11085  2005  PHO      Joe Johnson   23  82  3240  15.1  0.556  0.314  0.153
# 11086  2005  HOU    Tracy McGrady   25  78  3182  22.9  0.526  0.262  0.336
#
#           ...       d_worp  adjusted_worp  estimated_position  bbref_pos  \
# 11082     ...          4.1           20.3                 2.8        3.0
# 11083     ...         -4.2           10.6                 1.0        1.0
# 11084     ...         -2.7           11.7                 1.2        1.0
# 11085     ...          0.3            8.3                 2.9        3.0
# 11086     ...          4.7           17.2                 2.4        3.0
#
# ...

# %%
# make columns easier

basic_df.columns = basic_df.columns.str.replace(' ', '_')

# %%
basic_df = basic_df.rename(columns={'Season_Start':'year', 'Player_Name':'name', 
                                    'Player_Salary_in_$':'salary'})

# change salary back to float64
basic_df['salary'] = basic_df['salary'].apply(pd.to_numeric)

# %%
basic_df[basic_df['name']=='Kevin Durant']
# Out:
#          year          name      salary Pos   Age   Tm     G    GS      MP  \
# 13951  2008.0  Kevin Durant   4484040.0  SG  19.0  SEA  80.0  80.0  2768.0
# 13952  2009.0  Kevin Durant   4796880.0  SF  20.0  OKC  74.0  74.0  2885.0
# 13953  2010.0  Kevin Durant   6053663.0  SF  21.0  OKC  82.0  82.0  3239.0
# 13954  2011.0  Kevin Durant  15506632.0  SF  22.0  OKC  78.0  78.0  3038.0
# 13955  2012.0  Kevin Durant  16669630.0  SF  23.0  OKC  66.0  66.0  2546.0
# 13956  2013.0  Kevin Durant  17832627.0  SF  24.0  OKC  81.0  81.0  3119.0
# 13957  2014.0  Kevin Durant  18995624.0  SF  25.0  OKC  81.0  81.0  3122.0
# 13958  2015.0  Kevin Durant  20158622.0  SF  26.0  OKC  27.0  27.0   913.0
# 13959  2016.0  Kevin Durant  26540100.0  SF  27.0  OKC  72.0  72.0  2578.0
# 13960  2017.0  Kevin Durant  25000000.0  SF  28.0  GSW  62.0  62.0  2070.0
#
#         PER   ...      FT%    ORB    DRB    TRB    AST    STL    BLK    TOV  \
# ...

# %%
basic_df.columns
# Out:
# Index(['year', 'name', 'salary', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%',
#        'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# replace NaN with column averages and change to float for calculations

basic_df['salary'] = basic_df['salary'].fillna(basic_df['salary'].mean())
basic_df['salary'] = basic_df['salary'].astype(float)

# %%
basic_df['PER'] = basic_df['PER'].fillna(basic_df['PER'].mean())
basic_df['PER'] = basic_df['PER'].astype(float)

basic_df['TS%'] = basic_df['TS%'].fillna(basic_df['TS%'].mean())
basic_df['TS%'] = basic_df['TS%'].astype(float)

basic_df['3PAr'] = basic_df['3PAr'].fillna(basic_df['3PAr'].mean())
basic_df['3PAr'] = basic_df['3PAr'].astype(float)

basic_df['FTr'] = basic_df['FTr'].fillna(basic_df['FTr'].mean())
basic_df['FTr'] = basic_df['FTr'].astype(float)

basic_df['ORB%'] = basic_df['ORB%'].fillna(basic_df['ORB%'].mean())
basic_df['ORB%'] = basic_df['ORB%'].astype(float)

basic_df['DRB%'] = basic_df['DRB%'].fillna(basic_df['DRB%'].mean())
basic_df['DRB%'] = basic_df['DRB%'].astype(float)

basic_df['TRB%'] = basic_df['TRB%'].fillna(basic_df['TRB%'].mean())
basic_df['TRB%'] = basic_df['TRB%'].astype(float)

basic_df['AST%'] = basic_df['AST%'].fillna(basic_df['AST%'].mean())
basic_df['AST%'] = basic_df['AST%'].astype(float)

basic_df['STL%'] = basic_df['STL%'].fillna(basic_df['STL%'].mean())
basic_df['STL%'] = basic_df['STL%'].astype(float)

basic_df['BLK%'] = basic_df['BLK%'].fillna(basic_df['BLK%'].mean())
basic_df['BLK%'] = basic_df['BLK%'].astype(float)

basic_df['TOV%'] = basic_df['TOV%'].fillna(basic_df['TOV%'].mean())
basic_df['TOV%'] = basic_df['TOV%'].astype(float)

basic_df['USG%'] = basic_df['USG%'].fillna(basic_df['USG%'].mean())
basic_df['USG%'] = basic_df['USG%'].astype(float)

basic_df['FG%'] = basic_df['FG%'].fillna(basic_df['FG%'].mean())
basic_df['FG%'] = basic_df['FG%'].astype(float)

basic_df['3P%'] = basic_df['3P%'].fillna(basic_df['3P%'].mean())
basic_df['3P%'] = basic_df['3P%'].astype(float)

basic_df['2P%'] = basic_df['2P%'].fillna(basic_df['2P%'].mean())
basic_df['2P%'] = basic_df['2P%'].astype(float)

basic_df['FT%'] = basic_df['FT%'].fillna(basic_df['FT%'].mean())
basic_df['FT%'] = basic_df['FT%'].astype(float)

basic_df['WS/48'] = basic_df['WS/48'].fillna(basic_df['WS/48'].mean())
basic_df['WS/48'] = basic_df['WS/48'].astype(float)

basic_df['eFG%'] = basic_df['eFG%'].fillna(basic_df['eFG%'].mean())
basic_df['eFG%'] = basic_df['eFG%'].astype(float)

# %%
basic_df.head()
# Out:
#       year          name        salary Pos   Age   Tm     G    GS      MP  \
# 24  2017.0  A.J. Hammons  1.312611e+06   C  24.0  DAL  22.0   0.0   163.0
# 25  2010.0    A.J. Price  7.621950e+05  PG  23.0  IND  56.0   2.0   865.0
# 26  2011.0    A.J. Price  8.543890e+05  PG  24.0  IND  50.0   0.0   795.0
# 27  2012.0    A.J. Price  8.851200e+05  PG  25.0  IND  44.0   1.0   568.0
# 28  2013.0    A.J. Price  5.143812e+06  PG  26.0  WAS  57.0  22.0  1278.0
#
#      PER  ...      FT%   ORB   DRB    TRB    AST   STL   BLK   TOV    PF  \
# 24   8.4  ...    0.450   8.0  28.0   36.0    4.0   1.0  13.0  10.0  21.0
# 25  14.0  ...    0.800  12.0  76.0   88.0  106.0  35.0   3.0  59.0  53.0
# 26  10.7  ...    0.667  16.0  56.0   72.0  111.0  29.0   1.0  53.0  61.0
# 27  11.5  ...    0.800  13.0  48.0   61.0   86.0  20.0   2.0  32.0  30.0
# 28  12.4  ...    0.790  20.0  94.0  114.0  205.0  33.0   3.0  64.0  73.0
#
#       PTS
# 24   48.0
# 25  410.0
# 26  323.0
# 27  172.0
# 28  441.0
#
# ...

# %%
# Normalize popular stats to per game basis

# minutes per game
basic_df["M_PG"] = basic_df['MP']/basic_df['G']

# normalize pts scored to ppg
basic_df['P_PG'] = basic_df['PTS']/basic_df['G']

# assists
basic_df['A_PG'] = basic_df['AST']/basic_df['G']

# rbds
basic_df['R_PG'] = (basic_df['ORB']+basic_df['DRB'])/basic_df['G']

# OPG
basic_df['OR_PG'] = basic_df['ORB']/basic_df['G']

# DPG
basic_df['DR_PG'] = basic_df['DRB']/basic_df['G']

# steals
basic_df['STL_PG'] = basic_df['STL']/basic_df['G']

# blocks
basic_df['BLK_PG'] = basic_df['BLK']/basic_df['G']

# turnover
basic_df['TOV_PG'] = basic_df['TOV']/basic_df['G']

# 3P
basic_df['3P_PG'] = basic_df['3P']/basic_df['G']

# 3PA
basic_df['3PA_PG'] = basic_df['3PA']/basic_df['G']

# freethrow
basic_df['FT_PG'] = basic_df['FT']/basic_df['G']

# FG
basic_df['FG_PG'] = basic_df['FG']/basic_df['G']

# 2P
basic_df['2P_PG'] = basic_df['2P']/basic_df['G']

# 2PA
basic_df['2PA_PG'] = basic_df['2PA']/basic_df['G']

# FGA
basic_df['FGA_PG'] = basic_df['FGA']/basic_df['G']

# FTA
basic_df['FTA_PG'] = basic_df['FTA']/basic_df['G']

# PF
basic_df['PF_PG'] = basic_df['PF']/basic_df['G']

# %%
basic_df[basic_df['name'] == 'LeBron James']
# Out:
#          year          name        salary Pos   Age   Tm     G    GS      MP  \
# 14936  2005.0  LeBron James  4.621800e+06  SF  20.0  CLE  80.0  80.0  3388.0
# 14937  2006.0  LeBron James  5.828090e+06  SF  21.0  CLE  79.0  79.0  3361.0
# 14938  2007.0  LeBron James  1.304125e+07  SF  22.0  CLE  78.0  78.0  3190.0
# 14939  2008.0  LeBron James  1.441058e+07  SF  23.0  CLE  75.0  74.0  3027.0
# 14940  2009.0  LeBron James  1.577991e+07  SF  24.0  CLE  81.0  81.0  3054.0
# 14941  2010.0  LeBron James  5.143812e+06  SF  25.0  CLE  76.0  76.0  2966.0
# 14942  2011.0  LeBron James  1.602250e+07  SF  26.0  MIA  79.0  79.0  3063.0
# 14943  2012.0  LeBron James  1.754500e+07  SF  27.0  MIA  62.0  62.0  2326.0
# 14944  2013.0  LeBron James  1.906750e+07  PF  28.0  MIA  76.0  76.0  2877.0
# 14945  2014.0  LeBron James  2.064440e+07  PF  29.0  MIA  77.0  77.0  2902.0
# 14946  2015.0  LeBron James  2.297100e+07  SF  30.0  CLE  69.0  69.0  2493.0
# ...

# %%
basic_df.columns
# Out:
# Index(['year', 'name', 'salary', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%',
#        'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'M_PG', 'P_PG', 'A_PG', 'R_PG', 'OR_PG', 'DR_PG',
#        'STL_PG', 'BLK_PG', 'TOV_PG', '3P_PG', '3PA_PG', 'FT_PG', 'FG_PG',
#        '2P_PG', '2PA_PG', 'FGA_PG', 'FTA_PG', 'PF_PG'],
#       dtype='object')

# %%
basic_df['PTS'].head(20)
# Out:
# 24      48.0
# 25     410.0
# 26     323.0
# 27     172.0
# 28     441.0
# 29      44.0
# 30     133.0
# 31     105.0
# 32      22.0
# 33       6.0
# 36     264.0
# 37     894.0
# 38    1604.0
# 39     634.0
# 40     394.0
# 41     240.0
# 42     376.0
# 43     366.0
# 44      10.0
# 45     645.0
# Name: PTS, dtype: float64

# %%
# Average Salary by year
basic_df.groupby('year').salary.mean()
# Out:
# year
# 2005.0    4.631443e+06
# 2006.0    4.574117e+06
# 2007.0    4.935480e+06
# 2008.0    5.135725e+06
# 2009.0    4.990190e+06
# 2010.0    4.943374e+06
# 2011.0    5.071963e+06
# 2012.0    5.000953e+06
# 2013.0    4.890129e+06
# 2014.0    4.607614e+06
# 2015.0    5.061866e+06
# 2016.0    6.141540e+06
# 2017.0    6.843484e+06
# Name: salary, dtype: float64

# %%
average = pd.DataFrame(basic_df.groupby('year').salary.mean())
average['year'] = average.index

_ = sns.set(style="whitegrid", rc={'figure.figsize':(14,5)})
_ = sns.barplot(x='year', y="salary", data=average)
_ = plt.xlabel('Year', fontsize=16)
_ = plt.ylabel('Average Salary ($)', fontsize=16)
_ = plt.title('NBA Average Salary (2005-2017)', fontsize=18)

# %%
# salary cap values 2005-2017

# 2005: 49500000
# 2006: 53135000
# 2007: 58680000
# 2008: 58680000
# 2009: 57700000
# 2010: 58044000
# 2011: 58044000
# 2012: 58044000
# 2013: 58679000
# 2014: 63065000
# 2015: 70000000
# 2016: 94143000
# 2017: 99093000

# lets normalize the salaries due to inflation, basically % of cap / dollars

basic_df.loc[basic_df.year == 2005, 'cap'] = basic_df.salary / 49500000
basic_df.loc[basic_df.year == 2006, 'cap'] = basic_df.salary / 53135000
basic_df.loc[basic_df.year == 2007, 'cap'] = basic_df.salary / 58680000
basic_df.loc[basic_df.year == 2008, 'cap'] = basic_df.salary / 58680000
basic_df.loc[basic_df.year == 2009, 'cap'] = basic_df.salary / 57700000
basic_df.loc[basic_df.year == 2010, 'cap'] = basic_df.salary / 58044000
basic_df.loc[basic_df.year == 2011, 'cap'] = basic_df.salary / 58044000
basic_df.loc[basic_df.year == 2012, 'cap'] = basic_df.salary / 58044000
basic_df.loc[basic_df.year == 2013, 'cap'] = basic_df.salary / 58679000
basic_df.loc[basic_df.year == 2014, 'cap'] = basic_df.salary / 63065000
basic_df.loc[basic_df.year == 2015, 'cap'] = basic_df.salary / 70000000
basic_df.loc[basic_df.year == 2016, 'cap'] = basic_df.salary / 94143000
basic_df.loc[basic_df.year == 2017, 'cap'] = basic_df.salary / 99093000

basic_df.head()
# Out:
#       year          name        salary Pos   Age   Tm     G    GS      MP  \
# 24  2017.0  A.J. Hammons  1.312611e+06   C  24.0  DAL  22.0   0.0   163.0
# 25  2010.0    A.J. Price  7.621950e+05  PG  23.0  IND  56.0   2.0   865.0
# 26  2011.0    A.J. Price  8.543890e+05  PG  24.0  IND  50.0   0.0   795.0
# 27  2012.0    A.J. Price  8.851200e+05  PG  25.0  IND  44.0   1.0   568.0
# 28  2013.0    A.J. Price  5.143812e+06  PG  26.0  WAS  57.0  22.0  1278.0
#
#      PER    ...        3P_PG    3PA_PG     FT_PG     FG_PG     2P_PG  \
# 24   8.4    ...     0.227273  0.454545  0.409091  0.772727  0.545455
# 25  14.0    ...     1.071429  3.107143  1.071429  2.589286  1.517857
# 26  10.7    ...     0.820000  2.980000  1.080000  2.280000  1.460000
# 27  11.5    ...     0.590909  2.000000  0.636364  1.340909  0.750000
# 28  12.4    ...     1.228070  3.508772  0.859649  2.824561  1.596491
#
#       2PA_PG    FGA_PG    FTA_PG     PF_PG       cap
# ...

# %%
# NBA cap by year

data = [['2005',49500000], ['2006', 53135000], ['2007', 58680000], ['2008', 58680000], ['2009', 57700000],
       ['2010', 58044000], ['2011', 58044000], ['2012',58044000], ['2013', 58679000], ['2014', 63065000],
       ['2015', 70000000], ['2016', 94143000], ['2017', 99093000]]
cap_by_year = pd.DataFrame(data, columns=['year', 'cap'])

_ = sns.set(style="whitegrid", rc={'figure.figsize':(14,5)})
_ = sns.barplot(x='year', y="cap", data=cap_by_year)
_ = plt.xlabel('Year', fontsize=16)
_ = plt.ylabel('Total Salary Cap ($)', fontsize=16)
_ = plt.ticklabel_format(style='plain', axis='y')
_ = plt.title('NBA Salary Cap', fontsize=18)

# %%
average_cap = pd.DataFrame(basic_df.groupby('year').cap.mean())
average_cap['year'] = average.index

_ = sns.set(style="whitegrid", rc={'figure.figsize':(14,5)})
_ = sns.barplot(x='year', y="cap", data=average_cap)
_ = plt.xlabel('Year', fontsize=16)
_ = plt.ylabel('Average %age', fontsize=16)
_ = plt.title('Average %age of Salary Cap', fontsize=18)

# %%
# correlation matrix

sns.set(style="white")

corr = basic_df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

plt.title('Correlation Matrix', fontsize=20)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            xticklabels=corr.columns, yticklabels=corr.columns,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# hard to read, Not usefull to me

# %%
# highest 15 R^2 values

print('15 highest R2 values for Salary')
print(corr['salary'].sort_values().tail(16))
# Out:
# 15 highest R2 values for Salary
# FT        0.518090
# FGA       0.518626
# 2P        0.519855
# VORP      0.527688
# FG        0.534412
# WS        0.537065
# PTS       0.538724
# FTA_PG    0.539023
# FT_PG     0.540417
# 2PA_PG    0.548764
# 2P_PG     0.556105
# FGA_PG    0.567020
# FG_PG     0.582650
# P_PG      0.587000
# cap       0.948324
# salary    1.000000
# Name: salary, dtype: float64

# %%
top_matrix = basic_df[['salary', 'FT', 'FTA', 'FGA', '2P', 'VORP', 'FG',
            'WS', 'PTS', 'FTA_PG', 'FT_PG', '2PA_PG', '2P_PG', 'FGA_PG',
                      'FG_PG', 'P_PG', 'cap']]

sns.set(style="white")

corr = top_matrix.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(10, 10))
plt.title('Top 15 Correlation Matrix', fontsize=20)
sns.heatmap(corr, mask=mask, xticklabels=corr.columns, yticklabels=corr.columns,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
sns.pairplot(top_matrix)

# %%
print('15 lowest R2 values for Salary')
print(corr['salary'].sort_values().head(16))

# %%
least_matrix = basic_df[['salary', 'TOV%', '3PAr', 'ORB%', 'STL%', 'BLK%', 'FTr',
            '3P%', 'TRB%', 'year', '2P%', 'FT%', 'eFG%', 'FG%', 'DBPM', 'DBPM',
                      'DRB%', 'TS%']]

sns.set(style="white")

corr = least_matrix.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(10, 10))
plt.title('(Least 15) Correlation Matrix', fontsize=20)
sns.heatmap(corr, mask=mask, xticklabels=corr.columns, yticklabels=corr.columns,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
# Machine Learning Model

# let's import
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
import statsmodels.api as sm
from statsmodels.api import OLS

# %%
# let's copy df into seperate one, just in case

df = pd.DataFrame(basic_df.copy())
train, test = train_test_split(df, stratify = df.year, test_size = 0.2, random_state = 42)

train.columns

# %%
to_drop = ['name', 'Pos', 'Tm']
ytrain = train.cap
xtrain = train.drop(to_drop, axis=1)

ytest = test.cap
xtest = test.drop(to_drop, axis=1)

# %%
ytrain.head()

# %%
# Let's do Mulitple Linear Regression

X = sm.add_constant(xtrain)
model = sm.OLS(ytrain, X).fit()
